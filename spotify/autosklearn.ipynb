# %%
import autosklearn.classification
import numpy as np
import pandas as pd

# %%
import autosklearn.classification
import sklearn.model_selection
import sklearn.datasets
import sklearn.metrics
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('train.csv', header=0)
data = data.drop(columns=['Unnamed: 0', 'track_id'])
data.replace({False: 0, True: 1}, inplace=True)

train, test = train_test_split(data, test_size=0.8, shuffle=True)

train_y = train['track_genre']
train_y = train_y.to_numpy()
train.drop(columns=('track_genre'))

train_X = train

# train_X = train_X.to_numpy()

test_y = test['track_genre']
test_y = test_y.to_numpy()
test.drop(columns=('track_genre'))

test_X = test

# test_X = test_X.to_numpy()

# %%
train_X.head()
# Out:
#                           artists                  album_name  \
# 27371               Pola & Bryson                Pacific - EP
# 19244  Dolly Parton;Michael Bublé             Merry Christmas
# 75589                 Liquid Mind  Liquid Mind XI: Deep Sleep
# 36692                   Stupeflip               Stup Religion
# 17846      Linn da Quebrada;MikeQ             PAJUBÁ REMIX II
#
#                            track_name  popularity  duration_ms  explicit  \
# 27371                         Abandon          19       327398         0
# 19244  Cuddle Up, Cozy Down Christmas           0       219169         0
# 75589               Compassion, Pt. 2          25       386120         0
# 36692                35 animaux morts          32       161573         0
# 17846          MikeQ * Tomara (Remix)          17       284307         0
#
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# ...

# %%
automl = autosklearn.classification.AutoSklearnClassifier()
automl.fit(train_X, train_y)
y_hat = automl.predict(test_X)
print("Accuracy score", sklearn.metrics.accuracy_score(test_y, y_hat))
# Out:
# /home/aless/.local/lib/python3.10/site-packages/autosklearn/data/feature_validator.py:318: UserWarning: Input Column artists has generic type object. Autosklearn will treat this column as string. Please ensure that this setting is suitable for your task.
#   warnings.warn(
# /home/aless/.local/lib/python3.10/site-packages/autosklearn/data/feature_validator.py:318: UserWarning: Input Column album_name has generic type object. Autosklearn will treat this column as string. Please ensure that this setting is suitable for your task.
#   warnings.warn(
# /home/aless/.local/lib/python3.10/site-packages/autosklearn/data/feature_validator.py:318: UserWarning: Input Column track_name has generic type object. Autosklearn will treat this column as string. Please ensure that this setting is suitable for your task.
#   warnings.warn(
# ...
